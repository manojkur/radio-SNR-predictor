# %%
import pandas as pd

# %%
csv_cols = [
    'spot',
    'timestamp',
    'reporter',
    'reporter_grid',
    'snr',
    'frequency',
    'tx_call',
    'tx_grid',
    'power',
    'drift',
    'distance',
    'azimuth',
    'band',
    'version',
    'code',
]
df = pd.read_csv('wsprspots-2018-03.csv', names=csv_cols, index_col=False)
df.head()
# Out:
#          spot   timestamp   reporter reporter_grid  snr  frequency tx_call  \
# 0  1092649310  1519862400    DC0DX/2        JO31lk   -1   0.137553  2E0ILY
# 1  1105538474  1519862400   DC0DX/MW        JO31lk   -1   0.137553  2E0ILY
# 2  1117377859  1519862400  DC0DX/MW1        JO31lk   -1   0.137553  2E0ILY
# 3  1102130221  1519862400   DC0DX/RF        JO31lk   -1   0.137553  2E0ILY
# 4  1090020813  1519862400   EA5DOM-1        IM98xn  -21   0.475653  EA3AER
#
#   tx_grid  power  drift  distance  azimuth  band    version  code
# 0  IO82qv     27      0       673      100    -1        NaN     0
# 1  IO82qv     27      0       673      100    -1        NaN     0
# 2  IO82qv     27      0       673      100    -1        NaN     0
# 3  IO82qv     27      0       673      100    -1        NaN     0
# 4  JN12kd     30      0       469      213     0  0.8_r3058     0

# %%
samp = df.sample(frac=0.0001)
samp.to_csv('wspr_testing.csv')

# %%
df[df['tx_call'] == 'W9NAA']
# Out:
#                 spot   timestamp   reporter reporter_grid  snr  frequency  \
# 11077485  1100278618  1520800200      AC7IJ        CN87vu  -27  14.097114
# 11077486  1100278981  1520800200      AF7KR        DM43bh  -15  14.097115
# 11077487  1100279056  1520800200    DM07SWL        DM07an  -14  14.097108
# 11077488  1100279174  1520800200     GM4SFW        IO77sn  -16  14.097118
# 11077489  1100278399  1520800200      K6MLE        CM98pr   -8  14.097113
# 11077490  1100278333  1520800200      K6PZB        CM88nk  -15  14.097103
# 11077491  1100280061  1520800200     KA7OEI          DN40  -13  14.097103
# 11077492  1100279021  1520800200     KC1CIG        FN53bt  -13  14.097141
# 11077493  1100280052  1520800200     KF7FBF        CN87ur  -18  14.097102
# 11077494  1100278748  1520800200       KL7L        BP51ip    4  14.097099
# 11077495  1100279324  1520800200     OE3XOE          JN87  -19  14.097542
# 11077496  1100278845  1520800200  TI4/N0URE        EK70wb   -2  14.097098
# ...
